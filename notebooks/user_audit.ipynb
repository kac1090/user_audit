# %%
import sys
sys.path.insert(1, '../src')
import user_audit as ua

# %%
employees_df, system_access_df = ua.load_data()

# %%
employees_df
# Out:
#     employee_number  first_name   last_name  \
# 0         EMP003037     Juliana    Burbudge
# 1         EMP003045      Lizzie        Blue
# 2         EMP003051     Marjory    Selcraig
# 3         EMP003068      Aguste    O'Connor
# 4         EMP003097     Clemens      Kopman
# ..              ...         ...         ...
# 970       EMP024864    Kristina       Yakov
# 971       EMP024885   Margarita  Habbergham
# 972       EMP024890    Prescott   Southward
# 973       EMP024896       Raine     Learned
# 974       EMP024931  Frederique        Fant
#
#                                     email              title
# 0        juliana.burbudge@consultants.com  Director of Sales
# 1             lizzie.blue@consultants.com    Sales Assistant
# 2        marjory.selcraig@consultants.com    Sales Assistant
# 3         aguste.o'connor@consultants.com    Sales Assistant
# 4          clemens.kopman@consultants.com    Account Manager
# ..                                    ...                ...
# ...

# %%
system_access_df
# Out:
#         id    access_level
# 0     3045  Contract Entry
# 1     3051  Contract Entry
# 2     3068  Contract Entry
# 3     3097   Account Admin
# 4     3133  Contract Entry
# ..     ...             ...
# 833  24862  Contract Entry
# 834  24864  Contract Entry
# 835  24885   Account Admin
# 836  24890  Contract Entry
# 837  24896   Account Admin
#
# [838 rows x 2 columns]

# %%
system_access_df = ua.clean_id(system_access_df)
system_access_df
# Out:
#             id    access_level
# 0    EMP003045  Contract Entry
# 1    EMP003051  Contract Entry
# 2    EMP003068  Contract Entry
# 3    EMP003097   Account Admin
# 4    EMP003133  Contract Entry
# ..         ...             ...
# 833  EMP024862  Contract Entry
# 834  EMP024864  Contract Entry
# 835  EMP024885   Account Admin
# 836  EMP024890  Contract Entry
# 837  EMP024896   Account Admin
#
# [838 rows x 2 columns]

# %%
master_df = ua.join_data(employees_df, system_access_df)
master_df
# Out:
#     employee_number  first_name   last_name  \
# 0         EMP003037     Juliana    Burbudge
# 1         EMP003045      Lizzie        Blue
# 2         EMP003051     Marjory    Selcraig
# 3         EMP003068      Aguste    O'Connor
# 4         EMP003097     Clemens      Kopman
# ..              ...         ...         ...
# 970       EMP024864    Kristina       Yakov
# 971       EMP024885   Margarita  Habbergham
# 972       EMP024890    Prescott   Southward
# 973       EMP024896       Raine     Learned
# 974       EMP024931  Frederique        Fant
#
#                                     email              title         id  \
# 0        juliana.burbudge@consultants.com  Director of Sales        NaN
# 1             lizzie.blue@consultants.com    Sales Assistant  EMP003045
# 2        marjory.selcraig@consultants.com    Sales Assistant  EMP003051
# 3         aguste.o'connor@consultants.com    Sales Assistant  EMP003068
# ...

# %%
master_df.isnull().sum()
# Out:
# employee_number      0
# first_name           0
# last_name            0
# email                0
# title                0
# id                 137
# access_level       137
# dtype: int64

# %%
null_data = ua.null_data(master_df)
null_data
# Out:
#     employee_number  first_name last_name                             email  \
# 0         EMP003037     Juliana  Burbudge  juliana.burbudge@consultants.com
# 8         EMP003265      Natala      Judd       natala.judd@consultants.com
# 10        EMP003291     Gweneth    Abbate    gweneth.abbate@consultants.com
# 26        EMP003684    Annmarie   Scrange  annmarie.scrange@consultants.com
# 28        EMP003713    Marybeth   Driussi  marybeth.driussi@consultants.com
# ..              ...         ...       ...                               ...
# 931       EMP024068     Celinka   Vasilic   celinka.vasilic@consultants.com
# 936       EMP024191       Danny    Vinten      danny.vinten@consultants.com
# 951       EMP024501      Fedora     Belle      fedora.belle@consultants.com
# 954       EMP024551        Ravi   Dighton      ravi.dighton@consultants.com
# 974       EMP024931  Frederique      Fant   frederique.fant@consultants.com
#
#                  title   id access_level
# ...
